# %%
#Код создания большого файла по всем УИКам
#Отработанный код 8 марта

import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import js2py
import numpy as np
from tqdm import tqdm
url_root = "http://www.vybory.izbirkom.ru/region/region/izbirkom?action=show&root=1&tvd=100100028713304&vrn=100100028713299&region=0&global=1&sub_region=0&prver=0&pronetvd=null&vibid=100100028713304&type=233"
# получить html-код сайта
r = requests.get(url_root)
soup = BeautifulSoup(r.text, "lxml")
# Найдем все ссылки на региональные ИК
urls = [i.get("href") for i in soup.findAll("a",{"style":"text-decoration: none"})]
urls = list(set(urls))
all_tables = []
non_format=[]
wrong_suburl = []
common_table = None
for url in tqdm(urls):
    try:        
        html_code = BeautifulSoup(requests.get(url).text, "lxml")
        # ссылка на таблицу находится в начале javascript
        needed_script = html_code.findAll("script")[0]
        js = needed_script.text.replace("window.location.assign", "return") + '\n(getXls());'
        table_url = js2py.eval_js(js)    
        table = pd.read_excel(table_url)
        foldername = " ".join(table.loc[2][0].split(':')[1].split())
#         os.makedirs('./' + foldername)
#         writer = pd.ExcelWriter('./' + foldername + '/' + foldername + '.xls')
#         table.to_excel(writer,'Sheet1')
#         writer.save()
    except:
        non_format.append(url)
        # Разобрались с ТИКами начнем с УИКами
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    new_urls = soup.findAll("a",{"style":"text-decoration: none"})
    for sub_url in [i.get("href") for i in new_urls]:
        r = requests.get(sub_url)
        soup = BeautifulSoup(r.text, "lxml")
        subb_url = soup.findAll(lambda tag: tag.text == 
                                'сайт избирательной комиссии субъекта Российской Федерации')
#         if len(subb_url) != 1:
#             print("wrong:")
#             print("parent url")
#             print(url)
#             print("error url")
#             print(sub_url)
#             wrong_suburl.append(sub_url)
#         else:
        if len(subb_url) == 1:
            url = subb_url[0].get('href')
            html_code = BeautifulSoup(requests.get(url).text, "lxml")
            # ссылка на таблицу находится в начале javascript
            needed_script = html_code.findAll("script")[0]
            js = needed_script.text.replace("window.location.assign", "return") + '\n(getXls());'
            table_url = js2py.eval_js(js)    
            table = pd.read_excel(table_url)
            name = " ".join(table.loc[2][0].split(':')[1].split())
            ind = np.where(table.values == "Сумма")
            new_table = table.iloc[ind[0][0]+1:,ind[1][0]+1:]
            new_col = table.iloc[ind[0][0],ind[1][0]+1:].values
            new_table.columns = new_col
            new_index = table.iloc[ind[0][0]+1:,ind[1][0]-1].values
            new_table.index = new_index
            a = table.iloc[ind[0][0]+1:,ind[1][0]-1].dropna().values
            new_table = new_table.loc[a].transpose()
            new_table['Название ТИК'] = name
            new_table['Название области'] = foldername 
            if common_table is None:
                common_table = pd.DataFrame(columns=new_table.columns)
            else:
                common_table = common_table.append(new_table)
#             writer = pd.ExcelWriter('./' + foldername + '/' + 'УИК_' + name + '.xls')
#             table.to_excel(writer,'Sheet1')
#             writer.save()
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/home/nazar/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/nazar/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/nazar/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 100%|██████████| 151/151 [1:35:31<00:00, 37.96s/it]

# %%
# сохранить нужную таблицу
common_table.to_csv('common.csv')

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import js2py
import numpy as np
from tqdm import tqdm
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats
table = pd.read_csv('common.csv', index_col=0)

# %%
# проверка на нормальность
normal_arr = []
for tik in set(table['Название области']):
    sub_table = table.loc[table['Название области'] == tik]
    tik_table = (sub_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
                 '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"'].divide(
    sub_table['Число избирательных бюллетеней, полученных участковой избирательной комиссией'].values, 
    axis=0))
    tik_table['Явка'] = tik_table.sum(axis=1)
    normal_arr.append((stats.mstats.normaltest(tik_table['Явка']).pvalue, tik))
normal_arr.sort()
normal_arr

# %%
#код отрисовки круты графиков

from matplotlib import rc
rc('font', size=15)
colour = ['k', 'g', 'c', 'r', 'm', 'b', 'y', 'w']
for tik in set(table['Название области']):
    sub_table = table.loc[table['Название области'] == tik]
    tik_table = (sub_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
                 '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"'].divide(
    sub_table['Число избирательных бюллетеней, полученных участковой избирательной комиссией'].values, 
    axis=0))
    tik_table['Явка'] = tik_table.sum(axis=1)
    (tik_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
              '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"']) = ((tik_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
              '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"']).divide(
              tik_table['Явка'].values, axis=0))
    tik_table['Количество голосов'] = sub_table['Число действительных избирательных бюллетеней']
    plt.figure(figsize=(20,10))
    plt.xlabel("Явка")
    plt.ylabel("Процент за")
    plt.grid()
    plt.title(tik)
    for i in range(7):
        partai = tik_table.columns[i]
        plt.scatter(tik_table.loc[:,'Явка'], 
                    tik_table.loc[:,partai], 
                    alpha = 0.15, 
                    s=tik_table.loc[:,'Количество голосов'] * tik_table.loc[:,partai],
                    c=colour[i],
                    label=partai.split('олитическая партия')[-1])
    plt.legend()
    plt.savefig(tik + '.pdf')
    plt.close()

# %%
from matplotlib import rc
rc('font', size=15)
colour = ['k', 'g', 'c', 'r', 'm', 'b', 'y', 'w']
common = None
for tik in set(table['Название области']):
    sub_table = table.loc[table['Название области'] == tik]
    tik_table = (sub_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
                     '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"'].divide(
                sub_table['Число избирательных бюллетеней, полученных участковой избирательной комиссией'].values, 
                axis=0))
    tik_table['Явка'] = tik_table.sum(axis=1)
    (tik_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
                  '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"']) = ((tik_table.loc[:,'1. Политическая партия СПРАВЕДЛИВАЯ РОССИЯ':
                  '7. Всероссийская политическая партия "ПРАВОЕ ДЕЛО"']).divide(
                  tik_table['Явка'].values, axis=0))
    tik_table['Количество голосов'] = sub_table['Число действительных избирательных бюллетеней']
    weights = (tik_table['Количество голосов'] / tik_table['Количество голосов'].sum()).values
    true_weighted_table = tik_table.loc[:,:"Явка"].multiply(weights, axis=0).sum()
    true_weighted_table['Количество голосов'] = tik_table['Количество голосов'].sum()
    if common is None:
        common = pd.DataFrame(columns=tik_table.columns)
    else:
        common = common.append(true_weighted_table, ignore_index=True)

plt.figure(figsize=(20,10))
plt.xlabel("Явка")
plt.ylabel("Процент за")
plt.grid()
plt.title("Россия")
tik_table = common
for i in range(7):
    partai = tik_table.columns[i]
    plt.scatter(tik_table.loc[:,'Явка'], 
                tik_table.loc[:,partai], 
                alpha = 0.15, 
                s=tik_table.loc[:,'Количество голосов'] * tik_table.loc[:,partai]/1000,
                c=colour[i],
                label=partai.split('олитическая партия')[-1])
plt.legend()
plt.savefig('Russia.pdf')
plt.show()
